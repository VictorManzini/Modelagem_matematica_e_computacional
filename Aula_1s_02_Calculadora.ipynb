# %% [markdown]
# # Utilizando Python como uma calculadora científica

# %%
print("Hello World!") # Este é um comentário que não será executado
# Out:
# Hello World!

# %% [markdown]
# ## Tipos de variáveis numéricas

# %% [markdown]
# ### Inteiros

# %%
5
# Out:
# 5

# %%
type(5)
# Out:
# int

# %% [markdown]
# ### Floats

# %%
5.0
# Out:
# 5.0

# %%
type(5.0)
# Out:
# float

# %%
6.32
# Out:
# 6.32

# %%
type(6.32)
# Out:
# float

# %% [markdown]
# ### Conversão e arredondamento

# %%
int(6.32)
# Out:
# 6

# %%
round(6.32)
# Out:
# 6

# %%
round(6.32,1)
# Out:
# 6.3

# %% [markdown]
# ### Complexos

# %%
c = complex(1, 2)

# %%
type(c)

# %%
c

# %%
c.real

# %%
c.imag

# %% [markdown]
# ## Quatro operações básicas

# %% [markdown]
# ### Soma
#
# $a+b$

# %%
1+1

# %% [markdown]
# ### Subtração
#
# $a-b$

# %%
9-7

# %% [markdown]
# ### Multiplicação
#
# $a \times b$

# %%
6*5

# %% [markdown]
# ### Divisão
#
# $\ a \div b$ ou $\frac{a}{b}$

# %%
90/9

# %% [markdown]
# ### Quociente e resto

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print(10/3)

# %% [markdown]
# ### Floor division (divisão inteira)
#
# Retorna o quociente inteiro mais próximo da divisão, arredondando para baixo

# %%
print(10//3)

# %% [markdown]
# ### Modulus
#
# Retorna o resto da divisão

# %%
print(10%3) #modulus

# %% [markdown]
# ### Exponenciação
#
# $a^b$

# %% [markdown]
# $5^2$

# %%
print(5**2)

# %% [markdown]
# $2^4$

# %%
print(2**4)

# %% [markdown]
# $16^{0.5}$

# %%
print(16**(0.5))

# %% [markdown]
# $16^{-1}$

# %%
16**(-1)

# %% [markdown]
#  $\frac{1}{16}$

# %%
1/16

# %% [markdown]
# ### Raiz quadrada

# %%
import math
math.sqrt(16)

# %%
from math import *

# Você pode diretamente utilizar as funções e constantes
print(sqrt(16))
print(pi)

# %%
import numpy as np
np.sqrt(16)

# %%
from numpy import *
np.sqrt(16)

# %% [markdown]
# A última importação sobrescreve a anterior no namespace atual.

# %%
print(sqrt is math.sqrt)
print(sqrt is np.sqrt)

# %%
print(type(sqrt))

# %% [markdown]
# ### Ordem das operações - Ver Slides

# %%
x = 8 / 4 + 5 * (3 + 1) - 7 % 4
print(x)

# %% [markdown]
# ### Constantes

# %%
#pi

# %%
import numpy

# %%
numpy.pi

# %%
numpy.e

# %% [markdown]
# ### Erros comuns

# %%
numpy.sqrt(-1)

# %%
numpy.divide(0,0)

# %%
type(numpy.array([1,]))

# %%
numpy.array([1]) / 0.

# %% [markdown]
# Notar que o numpy trabalha com um outro tipo de variável numérica: nd.array
#
# um array é uma estrutura para armazenar e recuperar dados.

# %%
numpy.log([-1])

# %% [markdown]
# # Atividades

# %% [markdown]
# Qual é o resultado final das seguintes contas?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Referências

# %% [markdown]
# É sempre importante ver a documentação dos pacotes:
#
# https://numpy.org/doc/stable/reference/routines.math.html
#
#
# Existem também cheat sheets que fazem um resumo de funções principais e seus usos:
#
# https://media.datacamp.com/legacy/image/upload/v1676302459/Marketing/Blog/Numpy_Cheat_Sheet.pdf
